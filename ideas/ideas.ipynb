# %% [markdown]
# # Ideas

# %% [markdown]
# Github Repo: https://github.com/kirisame-ame/GCI-Competition

# %% [markdown]
# A notebook which explains several decisions made after trial/error

# %% [markdown]
# ## Encoding

# %% [markdown]
# ### Frequency Encoding

# %% [markdown]
# ### One Hot Encoding

# %% [markdown]
# ## Imputing Missing Values

# %% [markdown]
# ### Zero Imputing

# %% [markdown]
# ### Mean Imputing

# %% [markdown]
# ### Grouped Mean Imputing

# %% [markdown]
# ### Model Prediction Imputing

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### EXT_SOURCES Ratio

# %% [markdown]
# catboost feature importances, from git commit 62455fbbe611fee09cc0c9fd65a7d7c501679fb1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Correlation between EXT_SOURCE_1 and EXT_SOURCE_2: 0.21344587477440544
# - Correlation between EXT_SOURCE_1 and EXT_SOURCE_3: 0.1873243239063459
# - Correlation between EXT_SOURCE_2 and EXT_SOURCE_3: 0.10959492675500972

# %% [markdown]
# given the low correlation and high importance of the 3 external sources, a ratio feature could prove to be useful

# %% [markdown]
# ### Important Features Neighbours

# %% [markdown]
# A Neighbouring Mean based on the most important features i.e. EXT_SOURCES and C_to_Annuity could extract more information from the data. The feature importance data also aligns with the findings found on https://www.kaggle.com/competitions/home-credit-default-risk/discussion/64821, which creates a 500 neighbours target mean feature.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# feature importance after Neighbouring target mean
